# %% [markdown]
# # DataFrame
# - 행열을 가진 2차원 자료구조
# - 여러개의 Series 묶음 자료형

# %% [markdown]
# ## DataFrame 생성

# %% [markdown]
# ## DataFrame 속성

# %% [markdown]
# ## DataFrame 메서드

# %% [markdown]
# ## 조회
# - 행열조회
#     - df.iloc[인덱스]
#     - df.loc[라벨]
# - 열조회
#     - df[컬럼명]

# %% [markdown]
# ### iloc (인덱스 위치)

# %% [markdown]
# ### loc
# 인데스라벨을 통해 조회

# %% [markdown]
# ### 컬럼라벨

# %% [markdown]
# ## 행 추가/삭제

# %% [markdown]
# ## 컬럼 추가/삭제

# %% [markdown]
# ## 정렬
